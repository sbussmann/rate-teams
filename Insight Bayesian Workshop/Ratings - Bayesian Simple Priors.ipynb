# %%
import os
import pandas as pd
import numpy as np
import pymc3 as pm

# %%
data_dir = os.path.join(os.path.pardir, 'data')

# %%
league_id = 40264
winloss = pd.read_csv(os.path.join(data_dir, "winloss_simpleprior_{}.csv".format(league_id)))

# %%
winloss.head(20)
# Out:
#        Team A                             Team B  Team A Wins  Index A  \
# 0        AHOC                          Gothrilla         True        0
# 1        AHOC                                BBN         True        0
# 2        AHOC                       Stonecutters         True        0
# 3        AHOC                          FlowChart         True        0
# 4        AHOC                  Lady and the BAMF         True        0
# 5        AHOC                           Swingers         True        0
# 6        AHOC                           Upstream         True        0
# 7        AHOC                              Tubbs         True        0
# 8        AHOC                       Stonecutters         True        0
# 9        AHOC                         Zerg Rush!         True        0
# 10       AHOC                         Turtle Boy         True        0
# 11       AHOC  Live Poultry, Fresh Killed (LPFK)         True        0
# 12       AHOC                          TuneSquad         True        0
# 13       AHOC                           JuJu Hex         True        0
# 14  Gothrilla                           Swingers        False        1
# 15  Gothrilla                          FlowChart         True        1
# 16  Gothrilla              Hucky McThrowandcatch         True        1
# 17  Gothrilla               SnakeCountryBromance        False        1
# 18  Gothrilla                         Zerg Rush!        False        1
# 19  Gothrilla                        GrassBurner         True        1
#
#     Index B
# 0         1
# 1         9
# 2        41
# 3         2
# 4        28
# 5         5
# 6        10
# 7        29
# 8        41
# 9         4
# 10        7
# 11        8
# 12        6
# 13       43
# 14        5
# 15        2
# 16       50
# 17       40
# 18        4
# 19        3

# %%
winloss.shape
# Out:
# (522, 5)

# %%
teams = set(np.append(winloss['Team A'].unique(), winloss['Team B'].unique()))

# %%
team1 = winloss['Index A'].values
team2 = winloss['Index B'].values

with pm.Model() as model:
    
    skills = pm.Normal('skills', mu=0, shape=len(teams))
    
    delta_skill = skills[team1] - skills[team2]

    p = 1 / (1 + np.exp(-delta_skill))
    win = pm.Bernoulli('win', p, observed=winloss['Team A Wins'].values)

# %%
with model:
    trace = pm.sample(1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [skills]
# 100%|██████████| 1500/1500 [00:03<00:00, 483.94it/s]

# %%
meanratings = trace.get_values('skills').mean(axis=0)

# %%
names = []
for i, meanrating in enumerate(meanratings):
    if i in winloss['Index A'].values:
        index = winloss['Index A'] == i
        name = winloss.loc[index, 'Team A'].unique()[0]
    else:
        index = winloss['Index B'] == i
        name = winloss.loc[index, 'Team B'].unique()[0]
    names.append(name)
#     print("{}: {:.3f}".format(name, meanrating))

# %%
ratingsdf = pd.DataFrame({
    'mean_rating': meanratings
}, index=names)

# %%
plusminus = pd.read_csv(os.path.join(data_dir, 'plusminus_{}.csv'.format(league_id)), index_col='Team Name')

# %%
totaldf = plusminus.join(ratingsdf, how='inner')

# %%
totaldf.sort_values('mean_rating', ascending=False)
# Out:
#                                             PlusMinus    divname  Wins  \
# AHOC                                              100  4/3 Div 1    14
# Injustice League                                  100  4/3 Div 2    14
# Pink Flamingos                                     58  5/2 Div 2    10
# SnakeCountryBromance                               33  5/2 Div 1     5
# Jack's Abby HAOS Lager                             46  4/3 Div 2    10
# Maverick                                           42  5/2 Div 2     9
# JuJu Hex                                           72  5/2 Div 2    11
# Upstream                                          119  4/3 Div 2    20
# Zerg Rush!                                         22  4/3 Div 1    10
# FlowChart                                          29  4/3 Div 1    12
# Puddingstone                                       98  4/3 Div 2    18
# Gothrilla                                          47  4/3 Div 1    12
# Baba Yaga                                          47  5/2 Div 2     9
# Stonecutters                                       24  5/2 Div 1     8
# Too Drunk to Fail                                  59  4/3 Div 3    11
# License to Kilt (fka Scoobers in Scotland)         46  4/3 Div 2    13
# Flaming Croissants                                 66  4/3 Div 2    15
# Hippos                                             26  5/2 Div 2     9
# Bacon                                              18  5/2 Div 2     7
# Rubs The Duckie                                    30  4/3 Div 2     9
# GrassBurner                                        29  4/3 Div 1    11
# Toads                                              40  4/3 Div 2    15
# JHOP                                               32  4/3 Div 2    12
# Hucky McThrowandcatch                              -1  5/2 Div 2     5
# Flying Salsa                                       13  5/2 Div 3    12
# Get Flat Ultimate                                   2  5/2 Div 2    10
# Oddjob                                             11  4/3 Div 3    13
# Granite State Grass Stains                         22  5/2 Div 3     6
# Store Bought Dirt                                   8  4/3 Div 2    13
# SHRedline                                          -6  5/2 Div 2     6
# ...                                               ...        ...   ...
# Rabbit Disc                                        37  5/2 Div 3    12
# Fetch                                               9  4/3 Div 2     8
# Shake and Bake                                    -34  5/2 Div 1     3
# Demons                                             12  5/2 Div 3     5
# Live Poultry, Fresh Killed (LPFK)                 -39  4/3 Div 1     6
# The Funky Bunch                                   -29  5/2 Div 2     4
# A Lil Bit Sticky                                  -43  4/3 Div 2     5
# Alpha No Beta                                      -7  5/2 Div 3    10
# Moose Lightning                                   -65  4/3 Div 2     4
# Nerd Alert                                        -54  4/3 Div 2     7
# Baboon Heart                                      -35  4/3 Div 3     5
# Batman and the Robins                              -3  4/3 Div 3     6
# BBN                                               -47  4/3 Div 1     2
# Spam                                              -36  5/2 Div 3     9
# Stack to the Future                                -7  4/3 Div 3     9
# Tofu Wolf                                         -15  5/2 Div 3    11
# Underwater Monkey Cowboys                         -24  4/3 Div 3     6
# Lady and the BAMF                                 -74  4/3 Div 2     5
# SIR!                                              -53  5/2 Div 3     4
# Top Shelf                                         -35  4/3 Div 3     2
# Iron Squids                                       -33  5/2 Div 2     1
# Hipster Kitties                                   -98  4/3 Div 2     3
# Jiggy                                             -48  5/2 Div 3     5
# M.O.B.                                            -58  5/2 Div 3     2
# Tubbs                                             -89  4/3 Div 2     2
# Killer Bees                                       -35  5/2 Div 3     3
# 123 Trap!                                         -81  4/3 Div 3     1
# THEM!                                             -35  5/2 Div 3     2
# Spawning Alewives                                 -84  5/2 Div 3     1
# TuneSquad Squared                                -130  4/3 Div 2     0
#
#                                             Losses  Ties  mean_rating
# AHOC                                             0     0     2.390124
# Injustice League                                 1     0     1.740046
# Pink Flamingos                                   1     0     1.607249
# SnakeCountryBromance                             0     0     1.572911
# Jack's Abby HAOS Lager                           2     0     1.544915
# Maverick                                         2     1     1.436973
# JuJu Hex                                         3     1     1.399483
# Upstream                                         6     0     1.335988
# Zerg Rush!                                       4     0     1.332652
# FlowChart                                        4     0     1.245363
# Puddingstone                                     6     0     1.238573
# Gothrilla                                        4     1     1.215791
# Baba Yaga                                        3     0     1.156263
# Stonecutters                                     4     1     1.113132
# Too Drunk to Fail                                2     0     0.827492
# License to Kilt (fka Scoobers in Scotland)       6     0     0.819346
# Flaming Croissants                               5     0     0.816103
# Hippos                                           4     0     0.790467
# Bacon                                            4     0     0.646136
# Rubs The Duckie                                  4     0     0.640197
# GrassBurner                                      8     2     0.627990
# Toads                                            8     0     0.413701
# JHOP                                             8     1     0.343859
# Hucky McThrowandcatch                            5     0     0.293899
# Flying Salsa                                     8     0     0.265139
# Get Flat Ultimate                                8     0     0.227101
# Oddjob                                           6     0     0.227063
# Granite State Grass Stains                       4     0     0.187029
# Store Bought Dirt                               11     0     0.097953
# SHRedline                                        8     0     0.073736
# ...                                            ...   ...          ...
# Rabbit Disc                                      8     0    -0.164899
# Fetch                                           11     0    -0.199184
# Shake and Bake                                   7     3    -0.202899
# Demons                                           6     0    -0.287933
# Live Poultry, Fresh Killed (LPFK)               13     0    -0.304029
# The Funky Bunch                                  6     0    -0.311203
# A Lil Bit Sticky                                10     0    -0.379649
# Alpha No Beta                                    9     0    -0.417630
# Moose Lightning                                 11     0    -0.493313
# Nerd Alert                                      12     0    -0.512388
# Baboon Heart                                     7     0    -0.591429
# Batman and the Robins                            6     0    -0.638692
# BBN                                              8     1    -0.653180
# Spam                                            12     0    -0.687073
# Stack to the Future                             12     0    -0.698142
# Tofu Wolf                                       14     0    -0.757244
# Underwater Monkey Cowboys                       11     1    -0.930884
# Lady and the BAMF                               15     0    -0.985171
# SIR!                                            12     0    -1.053147
# Top Shelf                                        8     0    -1.135408
# Iron Squids                                     10     0    -1.178862
# Hipster Kitties                                 15     0    -1.288689
# Jiggy                                           14     1    -1.348217
# M.O.B.                                          10     0    -1.396209
# Tubbs                                           15     0    -1.570161
# Killer Bees                                     12     0    -1.587181
# 123 Trap!                                        9     0    -1.695011
# THEM!                                           12     0    -1.778903
# Spawning Alewives                               11     0    -1.956628
# TuneSquad Squared                               17     0    -2.157602
#
# [67 rows x 6 columns]
